# %%
import tensorflow as tf

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, load_model
from keras.layers import Dense, Input, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import DenseNet121

# %%
disease_type = ['Healthy','Mosaic']
data_path = 'E:/Crop_disease/dataset/datasets/Field/Cluster_bean/'
train_dir = os.path.join(data_path)

# %%
os.listdir(train_dir)
# Out:
# ['Healthy', 'Mosaic']

# %%
train_data = []
for id, sp in enumerate(disease_type):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
train.head(500)
# Out:
#                                                   File  DiseaseID Disease Type
# 0    Healthy/.trashed-1668312159-IMG20221013165532.jpg          0      Healthy
# 1                        Healthy/IMG20221013164438.jpg          0      Healthy
# 2                        Healthy/IMG20221013164445.jpg          0      Healthy
# 3                        Healthy/IMG20221013164450.jpg          0      Healthy
# 4                        Healthy/IMG20221013164454.jpg          0      Healthy
# ..                                                 ...        ...          ...
# 495                     Mosaic/IMG_20221013_165412.jpg          1       Mosaic
# 496                     Mosaic/IMG_20221013_165420.jpg          1       Mosaic
# 497                     Mosaic/IMG_20221013_165431.jpg          1       Mosaic
# 498                     Mosaic/IMG_20221013_165434.jpg          1       Mosaic
# 499                     Mosaic/IMG_20221013_165441.jpg          1       Mosaic
#
# [500 rows x 3 columns]

# %%
len(train)
# Out:
# 695

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                              File  DiseaseID Disease Type
# 0   Healthy/IMG20221015075636.jpg          0      Healthy
# 1  Mosaic/IMG_20221013_172013.jpg          1       Mosaic
# 2   Healthy/IMG20221013171258.jpg          0      Healthy
# 3   Healthy/IMG20221015074756.jpg          0      Healthy
# 4   Healthy/IMG20221015074152.jpg          0      Healthy

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_path, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('Mosaic', 5, 5)

# %%
IMAGE_SIZE = 64

def read_image(filepath):
    return cv2.imread(os.path.join(data_path, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 695it [02:50,  4.07it/s]
# Train Shape: (695, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 15))
for i in range(2):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_type[np.argmax(Y_train[i])])

# %%
EPOCHS = 100
SIZE=64
N_ch=3

# %%
def build_densenet():
    densenet = DenseNet121(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = densenet(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.002, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
from collections import Counter
print(Counter(train['Disease Type']))
# Out:
# Counter({'Healthy': 480, 'Mosaic': 215})

# %%
class_weights = {0:480/588, 1:215/588}

# %%
class_weights
# Out:
# {0: 0.8163265306122449, 1: 0.3656462585034014}

# %%
model = build_densenet()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=16),
               steps_per_epoch=X_train.shape[0] // 16,
               epochs=100,
               verbose=2,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val),
               class_weight = class_weights)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 3)         84
#
#  densenet121 (Functional)    (None, None, None, 1024)  7037504
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 2)                 514
#
# =================================================================
# Total params: 7,305,622
# Trainable params: 7,219,414
# Non-trainable params: 86,208
# _________________________________________________________________
# C:\Users\User1\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# C:\Users\User1\AppData\Local\Temp\26\ipykernel_26468\772981173.py:14: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=16),
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.72884, saving model to model.h5
# 34/34 - 34s - loss: 0.8006 - accuracy: 0.5593 - val_loss: 0.7288 - val_accuracy: 0.4317 - lr: 0.0020 - 34s/epoch - 1s/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.72884 to 0.52056, saving model to model.h5
# 34/34 - 7s - loss: 0.6797 - accuracy: 0.6130 - val_loss: 0.5206 - val_accuracy: 0.7266 - lr: 0.0020 - 7s/epoch - 197ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.52056
# 34/34 - 5s - loss: 0.5773 - accuracy: 0.7111 - val_loss: 0.5513 - val_accuracy: 0.7554 - lr: 0.0020 - 5s/epoch - 155ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.52056
# 34/34 - 5s - loss: 0.4408 - accuracy: 0.7481 - val_loss: 0.7147 - val_accuracy: 0.6906 - lr: 0.0020 - 5s/epoch - 152ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.52056
# 34/34 - 5s - loss: 0.3561 - accuracy: 0.7944 - val_loss: 0.7661 - val_accuracy: 0.6978 - lr: 0.0020 - 5s/epoch - 154ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.52056 to 0.44395, saving model to model.h5
# 34/34 - 7s - loss: 0.2891 - accuracy: 0.8333 - val_loss: 0.4440 - val_accuracy: 0.8417 - lr: 0.0020 - 7s/epoch - 193ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.44395 to 0.34482, saving model to model.h5
# 34/34 - 7s - loss: 0.1965 - accuracy: 0.8676 - val_loss: 0.3448 - val_accuracy: 0.8417 - lr: 0.0020 - 7s/epoch - 203ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.34482 to 0.31027, saving model to model.h5
# 34/34 - 7s - loss: 0.2051 - accuracy: 0.8852 - val_loss: 0.3103 - val_accuracy: 0.8777 - lr: 0.0020 - 7s/epoch - 198ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.31027
# 34/34 - 5s - loss: 0.1703 - accuracy: 0.8870 - val_loss: 0.6515 - val_accuracy: 0.7410 - lr: 0.0020 - 5s/epoch - 149ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.31027 to 0.22216, saving model to model.h5
# 34/34 - 7s - loss: 0.2417 - accuracy: 0.8389 - val_loss: 0.2222 - val_accuracy: 0.9065 - lr: 0.0020 - 7s/epoch - 206ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.22216
# 34/34 - 6s - loss: 0.2022 - accuracy: 0.8852 - val_loss: 0.8463 - val_accuracy: 0.6978 - lr: 0.0020 - 6s/epoch - 164ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.22216 to 0.21156, saving model to model.h5
# 34/34 - 8s - loss: 0.1636 - accuracy: 0.8889 - val_loss: 0.2116 - val_accuracy: 0.9209 - lr: 0.0020 - 8s/epoch - 231ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.21156
# 34/34 - 6s - loss: 0.2368 - accuracy: 0.8796 - val_loss: 0.2763 - val_accuracy: 0.9065 - lr: 0.0020 - 6s/epoch - 186ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.21156
# 34/34 - 6s - loss: 0.1771 - accuracy: 0.8907 - val_loss: 0.2912 - val_accuracy: 0.8921 - lr: 0.0020 - 6s/epoch - 182ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.21156 to 0.16536, saving model to model.h5
# 34/34 - 8s - loss: 0.1521 - accuracy: 0.9228 - val_loss: 0.1654 - val_accuracy: 0.9281 - lr: 0.0020 - 8s/epoch - 236ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.16536
# 34/34 - 6s - loss: 0.1432 - accuracy: 0.9056 - val_loss: 0.2585 - val_accuracy: 0.8777 - lr: 0.0020 - 6s/epoch - 190ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.16536
# 34/34 - 6s - loss: 0.1288 - accuracy: 0.9241 - val_loss: 0.2684 - val_accuracy: 0.8921 - lr: 0.0020 - 6s/epoch - 184ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.16536
# 34/34 - 6s - loss: 0.1302 - accuracy: 0.9148 - val_loss: 0.2363 - val_accuracy: 0.9065 - lr: 0.0020 - 6s/epoch - 171ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.16536
# 34/34 - 5s - loss: 0.1096 - accuracy: 0.9278 - val_loss: 0.1762 - val_accuracy: 0.9353 - lr: 0.0020 - 5s/epoch - 157ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.16536 to 0.16429, saving model to model.h5
# 34/34 - 8s - loss: 0.0791 - accuracy: 0.9407 - val_loss: 0.1643 - val_accuracy: 0.9137 - lr: 0.0020 - 8s/epoch - 249ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.16429 to 0.12348, saving model to model.h5
# 34/34 - 8s - loss: 0.1031 - accuracy: 0.9333 - val_loss: 0.1235 - val_accuracy: 0.9281 - lr: 0.0020 - 8s/epoch - 221ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.12348 to 0.09469, saving model to model.h5
# 34/34 - 7s - loss: 0.0962 - accuracy: 0.9389 - val_loss: 0.0947 - val_accuracy: 0.9568 - lr: 0.0020 - 7s/epoch - 215ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.09469 to 0.06474, saving model to model.h5
# 34/34 - 7s - loss: 0.0669 - accuracy: 0.9481 - val_loss: 0.0647 - val_accuracy: 0.9856 - lr: 0.0020 - 7s/epoch - 221ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.06474
# 34/34 - 6s - loss: 0.0659 - accuracy: 0.9519 - val_loss: 0.0825 - val_accuracy: 0.9568 - lr: 0.0020 - 6s/epoch - 170ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.06474
# 34/34 - 5s - loss: 0.0706 - accuracy: 0.9481 - val_loss: 0.1850 - val_accuracy: 0.9065 - lr: 0.0020 - 5s/epoch - 156ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.06474
# 34/34 - 5s - loss: 0.0718 - accuracy: 0.9519 - val_loss: 0.2661 - val_accuracy: 0.8993 - lr: 0.0020 - 5s/epoch - 148ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.06474
# 34/34 - 5s - loss: 0.1129 - accuracy: 0.9259 - val_loss: 0.4584 - val_accuracy: 0.8345 - lr: 0.0020 - 5s/epoch - 153ms/step
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 28: val_loss did not improve from 0.06474
# 34/34 - 5s - loss: 0.0786 - accuracy: 0.9296 - val_loss: 0.0816 - val_accuracy: 0.9712 - lr: 0.0020 - 5s/epoch - 151ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.06474
# 34/34 - 5s - loss: 0.0723 - accuracy: 0.9463 - val_loss: 0.1859 - val_accuracy: 0.9209 - lr: 0.0010 - 5s/epoch - 150ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.06474
# 34/34 - 5s - loss: 0.0612 - accuracy: 0.9407 - val_loss: 0.0668 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 156ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.06474
# 34/34 - 5s - loss: 0.0814 - accuracy: 0.9407 - val_loss: 0.1363 - val_accuracy: 0.9424 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.06474 to 0.04899, saving model to model.h5
# 34/34 - 7s - loss: 0.0548 - accuracy: 0.9537 - val_loss: 0.0490 - val_accuracy: 0.9856 - lr: 0.0010 - 7s/epoch - 204ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.04899
# 34/34 - 5s - loss: 0.0723 - accuracy: 0.9444 - val_loss: 0.0594 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 156ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.04899
# 34/34 - 5s - loss: 0.0473 - accuracy: 0.9574 - val_loss: 0.0545 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 35/100
#
# Epoch 35: val_loss improved from 0.04899 to 0.04733, saving model to model.h5
# 34/34 - 7s - loss: 0.0396 - accuracy: 0.9704 - val_loss: 0.0473 - val_accuracy: 0.9856 - lr: 0.0010 - 7s/epoch - 199ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.04733
# 34/34 - 5s - loss: 0.0607 - accuracy: 0.9556 - val_loss: 0.0546 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 154ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.04733
# 34/34 - 5s - loss: 0.0388 - accuracy: 0.9685 - val_loss: 0.0605 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.04733 to 0.04132, saving model to model.h5
# 34/34 - 7s - loss: 0.0581 - accuracy: 0.9556 - val_loss: 0.0413 - val_accuracy: 0.9928 - lr: 0.0010 - 7s/epoch - 196ms/step
# Epoch 39/100
#
# Epoch 39: val_loss improved from 0.04132 to 0.04028, saving model to model.h5
# 34/34 - 7s - loss: 0.0622 - accuracy: 0.9556 - val_loss: 0.0403 - val_accuracy: 0.9928 - lr: 0.0010 - 7s/epoch - 198ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.1265 - accuracy: 0.9370 - val_loss: 0.0823 - val_accuracy: 0.9568 - lr: 0.0010 - 5s/epoch - 158ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0535 - accuracy: 0.9630 - val_loss: 0.0457 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0547 - accuracy: 0.9648 - val_loss: 0.0572 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 156ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0418 - accuracy: 0.9778 - val_loss: 0.0533 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 156ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0771 - accuracy: 0.9500 - val_loss: 0.0590 - val_accuracy: 0.9712 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0608 - accuracy: 0.9574 - val_loss: 0.0626 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0571 - accuracy: 0.9611 - val_loss: 0.0509 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 154ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0583 - accuracy: 0.9630 - val_loss: 0.1529 - val_accuracy: 0.9568 - lr: 0.0010 - 5s/epoch - 158ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0546 - accuracy: 0.9556 - val_loss: 0.0540 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 149ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0400 - accuracy: 0.9685 - val_loss: 0.0782 - val_accuracy: 0.9712 - lr: 0.0010 - 5s/epoch - 150ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0212 - accuracy: 0.9907 - val_loss: 0.0581 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 159ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0360 - accuracy: 0.9741 - val_loss: 0.0501 - val_accuracy: 0.9712 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0400 - accuracy: 0.9667 - val_loss: 0.0512 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0364 - accuracy: 0.9796 - val_loss: 0.0607 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0444 - accuracy: 0.9778 - val_loss: 0.0879 - val_accuracy: 0.9640 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0434 - accuracy: 0.9722 - val_loss: 0.0661 - val_accuracy: 0.9640 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0228 - accuracy: 0.9870 - val_loss: 0.0482 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0381 - accuracy: 0.9648 - val_loss: 0.0657 - val_accuracy: 0.9712 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0331 - accuracy: 0.9722 - val_loss: 0.0684 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.04028
# 34/34 - 5s - loss: 0.0486 - accuracy: 0.9630 - val_loss: 0.0557 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 60/100
#
# Epoch 60: val_loss improved from 0.04028 to 0.03084, saving model to model.h5
# 34/34 - 7s - loss: 0.0147 - accuracy: 0.9870 - val_loss: 0.0308 - val_accuracy: 0.9856 - lr: 0.0010 - 7s/epoch - 196ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0531 - accuracy: 0.9630 - val_loss: 0.2656 - val_accuracy: 0.8777 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0622 - accuracy: 0.9519 - val_loss: 0.0417 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0409 - accuracy: 0.9685 - val_loss: 0.0602 - val_accuracy: 0.9712 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.1397 - accuracy: 0.9556 - val_loss: 0.0318 - val_accuracy: 0.9928 - lr: 0.0010 - 5s/epoch - 154ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0512 - accuracy: 0.9648 - val_loss: 0.0355 - val_accuracy: 0.9928 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0247 - accuracy: 0.9796 - val_loss: 0.0363 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 149ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0786 - accuracy: 0.9722 - val_loss: 0.1634 - val_accuracy: 0.9209 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0248 - accuracy: 0.9778 - val_loss: 0.0442 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0462 - accuracy: 0.9648 - val_loss: 0.0698 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0251 - accuracy: 0.9852 - val_loss: 0.0388 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0331 - accuracy: 0.9741 - val_loss: 0.0508 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 156ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0359 - accuracy: 0.9796 - val_loss: 0.0316 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.03084
# 34/34 - 5s - loss: 0.0233 - accuracy: 0.9852 - val_loss: 0.0318 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 74/100
#
# Epoch 74: val_loss improved from 0.03084 to 0.02711, saving model to model.h5
# 34/34 - 7s - loss: 0.0309 - accuracy: 0.9833 - val_loss: 0.0271 - val_accuracy: 0.9856 - lr: 0.0010 - 7s/epoch - 201ms/step
# Epoch 75/100
#
# Epoch 75: val_loss improved from 0.02711 to 0.02690, saving model to model.h5
# 34/34 - 7s - loss: 0.0294 - accuracy: 0.9778 - val_loss: 0.0269 - val_accuracy: 0.9856 - lr: 0.0010 - 7s/epoch - 198ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.02690
# 34/34 - 5s - loss: 0.0529 - accuracy: 0.9778 - val_loss: 0.0271 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 158ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.02690
# 34/34 - 5s - loss: 0.0252 - accuracy: 0.9833 - val_loss: 0.0276 - val_accuracy: 0.9928 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.02690
# 34/34 - 5s - loss: 0.1187 - accuracy: 0.9463 - val_loss: 0.0366 - val_accuracy: 0.9928 - lr: 0.0010 - 5s/epoch - 152ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.02690
# 34/34 - 5s - loss: 0.0323 - accuracy: 0.9815 - val_loss: 0.0342 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 147ms/step
# Epoch 80/100
#
# Epoch 80: val_loss improved from 0.02690 to 0.02254, saving model to model.h5
# 34/34 - 7s - loss: 0.0503 - accuracy: 0.9667 - val_loss: 0.0225 - val_accuracy: 0.9928 - lr: 0.0010 - 7s/epoch - 193ms/step
# Epoch 81/100
#
# Epoch 81: val_loss improved from 0.02254 to 0.02052, saving model to model.h5
# 34/34 - 7s - loss: 0.0270 - accuracy: 0.9759 - val_loss: 0.0205 - val_accuracy: 1.0000 - lr: 0.0010 - 7s/epoch - 205ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0291 - accuracy: 0.9870 - val_loss: 0.0268 - val_accuracy: 0.9928 - lr: 0.0010 - 5s/epoch - 159ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0262 - accuracy: 0.9815 - val_loss: 0.0351 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 150ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0287 - accuracy: 0.9796 - val_loss: 0.0314 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 150ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0337 - accuracy: 0.9796 - val_loss: 0.0559 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0421 - accuracy: 0.9685 - val_loss: 0.0523 - val_accuracy: 0.9712 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0311 - accuracy: 0.9759 - val_loss: 0.1235 - val_accuracy: 0.9568 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0304 - accuracy: 0.9761 - val_loss: 0.0593 - val_accuracy: 0.9640 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0287 - accuracy: 0.9870 - val_loss: 0.0841 - val_accuracy: 0.9640 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0469 - accuracy: 0.9741 - val_loss: 0.0509 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0283 - accuracy: 0.9741 - val_loss: 0.0382 - val_accuracy: 0.9928 - lr: 0.0010 - 5s/epoch - 150ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0225 - accuracy: 0.9796 - val_loss: 0.0431 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 151ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0335 - accuracy: 0.9796 - val_loss: 0.0469 - val_accuracy: 0.9712 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0499 - accuracy: 0.9704 - val_loss: 0.1150 - val_accuracy: 0.9424 - lr: 0.0010 - 5s/epoch - 150ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0201 - accuracy: 0.9907 - val_loss: 0.0430 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0721 - accuracy: 0.9704 - val_loss: 0.0333 - val_accuracy: 0.9928 - lr: 0.0010 - 5s/epoch - 155ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0400 - accuracy: 0.9704 - val_loss: 0.0840 - val_accuracy: 0.9640 - lr: 0.0010 - 5s/epoch - 154ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0562 - accuracy: 0.9537 - val_loss: 0.0446 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 153ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0553 - accuracy: 0.9706 - val_loss: 0.0338 - val_accuracy: 0.9856 - lr: 0.0010 - 5s/epoch - 154ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.02052
# 34/34 - 5s - loss: 0.0337 - accuracy: 0.9741 - val_loss: 0.0456 - val_accuracy: 0.9784 - lr: 0.0010 - 5s/epoch - 155ms/step

# %%
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0456 - accuracy: 0.9784
# Final Loss: 0.04562333971261978, Final Accuracy: 0.9784172773361206

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_type, yticklabels=disease_type)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# 5/5 [==============================] - 2s 56ms/step
# Text(0.5, 192.72222222222217, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.show()

# %%
# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
